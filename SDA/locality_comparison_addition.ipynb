# %% [markdown]
# # Locality Comparison
#
# Define a matrix of size n x n and perform a simple scaling operation on the same using `row major` and `column major` order. Compare the time required to do the same in the form of a table

# %%
import time, random
import pandas as pd
import numpy as np
from typing import List
from tqdm import tqdm
from copy import deepcopy

# %%
def get_square_matrix(n:int):
    A = np.random.randn(n, n)
    return A

def add_row_major(A, B):
    r, c = A.shape
    C = np.zeros((r, c))
    for i in range(r):
        for j in range(c):
            # Row major
            C[i][j] = A[i][j] + B[i][j]
    return C

def add_column_major(A, B):
    r, c = A.shape
    C = np.zeros((r, c))
    for i in range(r):
        for j in range(c):
            # Column major
            C[j][i] = A[j][i] + B[j][i]
    return C

# %%
# Define containers for keeping track of time, 
# repeat the experiment 5 times for every order & size and take an average of it eventually
time_container = []
n_trials = 5

# %%
for size in tqdm([64, 128, 256, 512, 768, 1024, 1536, 2048, 3072, 4096], desc = "Comparing for 12 sizes"):
    A = get_square_matrix(size)
    B = get_square_matrix(size)
    
    for tr in range(n_trials):
        # Row Major
        start = time.time()
        _ = add_row_major(A, B)
        time_elapsed = time.time() - start
        time_container.append([size, "Row Major", time_elapsed])
        
        # Column Major
        start = time.time()
        _ = add_column_major(A, B)
        time_elapsed = time.time() - start
        time_container.append([size, "Column Major", time_elapsed])
# Out:
# Comparing for 12 sizes: 100%|██████████| 10/10 [03:23<00:00, 20.31s/it]

# %%
# Look at the individual times taken across different trials
df = pd.DataFrame(time_container, columns = ["Size", "Order", "Time"])
df.T
# Out:
#               0             1          2             3          4   \
# Size          64            64         64            64         64
# Order  Row Major  Column Major  Row Major  Column Major  Row Major
# Time    0.005774      0.004232   0.003796      0.003225    0.00286
#
#                  5          6             7          8             9   ...  \
# Size             64         64            64         64            64  ...
# Order  Column Major  Row Major  Column Major  Row Major  Column Major  ...
# Time       0.003236   0.002563      0.002461   0.002209      0.002041  ...
#
#               90            91         92            93         94  \
# Size        4096          4096       4096          4096       4096
# Order  Row Major  Column Major  Row Major  Column Major  Row Major
# Time    8.833409     10.654626    8.86185     10.567527   8.751233
#
#                  95         96            97         98            99
# Size           4096       4096          4096       4096          4096
# Order  Column Major  Row Major  Column Major  Row Major  Column Major
# Time      10.638901   8.781264     10.374967   8.789226     10.527365
#
# [3 rows x 100 columns]

# %%
# Look at the aggregated times
df.groupby(by = ["Size", "Order"]).mean()
# Out:
#                         Time
# Size Order
# 64   Column Major   0.003039
#      Row Major      0.003440
# 128  Column Major   0.008278
#      Row Major      0.008464
# 256  Column Major   0.034228
#      Row Major      0.033684
# 512  Column Major   0.146794
#      Row Major      0.134214
# 768  Column Major   0.325629
#      Row Major      0.303321
# 1024 Column Major   0.653498
#      Row Major      0.552816
# 1536 Column Major   1.454881
#      Row Major      1.226656
# 2048 Column Major   2.655152
#      Row Major      2.231120
# 3072 Column Major   6.010170
#      Row Major      5.044548
# 4096 Column Major  10.552677
#      Row Major      8.803396
