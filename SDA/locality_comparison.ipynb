# %% [markdown]
# # Locality Comparison
#
# Define a matrix of size n x n and perform a simple scaling operation on the same using `row major` and `column major` order. Compare the time required to do the same in the form of a table

# %%
import time, random
import pandas as pd
import numpy as np
from typing import List
from tqdm import tqdm
from copy import deepcopy

# %%
def get_square_matrix(n:int):
    A = np.random.randn(n, n)
    return A

def scale_row_major(A, scaling_factor:int = 2):
    A = deepcopy(A)
    r, c = len(A), len(A[0])
    for i in range(r):
        for j in range(c):
            # Row major
            A[i][j] = A[i][j] * scaling_factor
    return A

def scale_column_major(A, scaling_factor:int = 2):
    A = deepcopy(A)
    r, c = len(A), len(A[0])
    for i in range(r):
        for j in range(c):
            # Column major
            A[j][i] = A[j][i] * scaling_factor
    return A

# %%
# Define containers for keeping track of time, 
# repeat the experiment 5 times for every order & size and take an average of it eventually
time_container = []
n_trials = 5

# %%
for size in tqdm([64, 128, 256, 512, 768, 1024, 1536, 2048, 3072, 4096, 6000], desc = "Comparing for 12 sizes"):
    A = get_square_matrix(size)
    for tr in range(n_trials):
        # Row Major
        start = time.time()
        _ = scale_row_major(A)
        time_elapsed = time.time() - start
        time_container.append([size, "Row Major", time_elapsed])
        
        # Column Major
        start = time.time()
        _ = scale_column_major(A)
        time_elapsed = time.time() - start
        time_container.append([size, "Column Major", time_elapsed])
# Out:
# Comparing for 12 sizes: 100%|██████████| 11/11 [06:11<00:00, 33.74s/it]

# %%
# Look at the individual times taken across different trials
df = pd.DataFrame(time_container, columns = ["Size", "Order", "Time"])
df.T
# Out:
#              0             1          2             3          4    \
# Size          64            64         64            64         64
# Order  Row Major  Column Major  Row Major  Column Major  Row Major
# Time    0.002228      0.002083   0.002092      0.002076   0.002102
#
#                 5          6             7          8             9    ...  \
# Size             64         64            64         64            64  ...
# Order  Column Major  Row Major  Column Major  Row Major  Column Major  ...
# Time       0.002025    0.00201      0.002011   0.002075      0.002065  ...
#
#              100           101        102           103        104  \
# Size        6000          6000       6000          6000       6000
# Order  Row Major  Column Major  Row Major  Column Major  Row Major
# Time   17.963508      18.64632  18.030059     18.594166   18.06867
#
#                 105        106           107        108           109
# Size           6000       6000          6000       6000          6000
# Order  Column Major  Row Major  Column Major  Row Major  Column Major
# Time      19.197866  18.430285     18.845284  18.031836     18.732883
#
# [3 rows x 110 columns]

# %%
# Look at the aggregated times
df.groupby(by = ["Size", "Order"]).mean()
# Out:
#                         Time
# Size Order
# 64   Column Major   0.002052
#      Row Major      0.002101
# 128  Column Major   0.008109
#      Row Major      0.007978
# 256  Column Major   0.032010
#      Row Major      0.032132
# 512  Column Major   0.131892
#      Row Major      0.129618
# 768  Column Major   0.296647
#      Row Major      0.295258
# 1024 Column Major   0.587078
#      Row Major      0.530971
# 1536 Column Major   1.292726
#      Row Major      1.193496
# 2048 Column Major   2.341392
#      Row Major      2.118794
# 3072 Column Major   5.278636
#      Row Major      4.745478
# 4096 Column Major   9.404401
#      Row Major      8.439283
# 6000 Column Major  18.803304
#      Row Major     18.104872
